# %% [markdown]
# # CEGE0004: Assignment 1
# # Data Process
# In this notebook I will process the dataset 'default of credit card client' before fitting models.

# %% [markdown]
# ## The Dataset
#
# I am working with the default of credit card clients Data Set from UCI Machine Learning Repository, to classify and predict customer defaults. The link of dataset is shown below:
#
# https://archive.ics.uci.edu/ml/datasets/default+of+credit+card+clients
#
# The dataset employes a binary variable, default (Yes = 1, No = 0), as the response variable. At the same time, the following 23 variables are used as explanatory variables:
#
# X1: Amount of the given credit: it includes both the individual consumer credit and his/her family credit.
#
# X2: Gender (1 = male; 2 = female).
#
# X3: Education (1 = graduate school; 2 = university; 3 = high school; 4 = others).
#
# X4: Marital status (1 = married; 2 = single; 3 = others).
#
# X5: Age (year).
#
# X6 - X11: History of past payment from April to September. (e.g. X6 = the repayment status in September; X7 = the repayment status in August; . . .) The measurement scale for the repayment status is: -1 = pay duly; 1 = payment delay for one month; . . .; 9 = payment delay for nine months and above.
#
# X12 - X17: Amount of bill statement. (e.g. X12 = amount of bill statement in September; X13 = amount of bill statement in August; . . .).
#
# X18 - X23: Amount of previous payment. (e.g. X18 = amount paid in September; X19 = amount paid in August, 2005; . . .).

# %% [markdown]
# ## Start working by importing the required packages and dataset

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
data = pd.read_csv("default of credit card clients.csv")
data
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# 0          1      20000    2          2         1   24      2      2     -1
# 1          2     120000    2          2         2   26     -1      2      0
# 2          3      90000    2          2         2   34      0      0      0
# 3          4      50000    2          2         1   37      0      0      0
# 4          5      50000    1          2         1   57     -1      0     -1
# ...      ...        ...  ...        ...       ...  ...    ...    ...    ...
# 29995  29996     220000    1          3         1   39      0      0      0
# 29996  29997     150000    1          3         2   43     -1     -1     -1
# 29997  29998      30000    1          2         2   37      4      3      2
# 29998  29999      80000    1          3         1   41      1     -1      0
# 29999  30000      50000    1          2         1   46      0      0      0
#
# ...

# %% [markdown]
# First of all, let us replace the null value in the dataset with the np.nan value

# %%
for value in data:
    # if the column contains non-numeric values
    if not isinstance(value, (int, float)):
        # replace the non-numeric values with NaN
        data.replace(value, np.nan, regex=True)
data
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# 0          1      20000    2          2         1   24      2      2     -1
# 1          2     120000    2          2         2   26     -1      2      0
# 2          3      90000    2          2         2   34      0      0      0
# 3          4      50000    2          2         1   37      0      0      0
# 4          5      50000    1          2         1   57     -1      0     -1
# ...      ...        ...  ...        ...       ...  ...    ...    ...    ...
# 29995  29996     220000    1          3         1   39      0      0      0
# 29996  29997     150000    1          3         2   43     -1     -1     -1
# 29997  29998      30000    1          2         2   37      4      3      2
# 29998  29999      80000    1          3         1   41      1     -1      0
# 29999  30000      50000    1          2         1   46      0      0      0
#
# ...

# %% [markdown]
# It is noted that the ID column is not relevant with model fitting and prediction so this column will be removed

# %% [markdown]
# Remove the ID column

# %%
data = data.drop(["ID"], axis=1)

# %% [markdown]
# Next, as the column LIMIT_BAL takes a wide range of values, from 10000 to 1000000, it is valuable to standardize its values

# %%
scaler = StandardScaler()
scaled_data = scaler.fit_transform(data["LIMIT_BAL"].array.reshape(-1, 1))
data['LIMIT_BAL'] = scaled_data.tolist()
data['LIMIT_BAL'] = data['LIMIT_BAL'].apply(lambda x: x[0])
data
# Out:
#        LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0      -1.136720    2          2         1   24      2      2     -1     -1
# 1      -0.365981    2          2         2   26     -1      2      0      0
# 2      -0.597202    2          2         2   34      0      0      0      0
# 3      -0.905498    2          2         1   37      0      0      0      0
# 4      -0.905498    1          2         1   57     -1      0     -1      0
# ...          ...  ...        ...       ...  ...    ...    ...    ...    ...
# 29995   0.404759    1          3         1   39      0      0      0      0
# 29996  -0.134759    1          3         2   43     -1     -1     -1     -1
# 29997  -1.059646    1          2         2   37      4      3      2     -1
# 29998  -0.674276    1          3         1   41      1     -1      0      0
# 29999  -0.905498    1          2         1   46      0      0      0      0
#
# ...

# %% [markdown]
# Subsequently, the result column is extracted from the dataset

# %%
result = data[["default payment next month"]]
data = data.drop("default payment next month", axis = 1)

# %% [markdown]
# Finally, divide the dataset to training set and test set

# %%
x_train, x_test, y_train, y_test = train_test_split(data,result,test_size = 0.2, random_state=0)

# %% [markdown]
# Create the training set csv and test set csv

# %%
x_train.to_csv("x_train.csv", index=False)
x_test.to_csv("x_test.csv", index=False)
y_train.to_csv("y_train.csv", index=False)
y_test.to_csv("y_test.csv", index=False)
